# %%
import json
from pathlib import Path
from production.functions.selection_resolver import resolve_selection_scope

# %%
policy_master_path = Path("/Users/li-hengfu/Documents/GitHub/demo-prior-auth/scripts/production/policy_artifacts/0314/policy_master_v4.json")
route_index_path = Path("/Users/li-hengfu/Documents/GitHub/demo-prior-auth/scripts/production/policy_artifacts/0314/route_index_v4.json")

def load_json_from_paths(path):
    with path.open("r", encoding="utf-8") as f:
        data = json.load(f)
    return data

# %%
policy_master_json = load_json_from_paths(policy_master_path)
route_index_json = load_json_from_paths(route_index_path)
billing_code = "J9311"
phase = "continuation"
cluster_id = "CL_ONC_HYCELA_CONT"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 policy_master_json = load_json_from_paths(policy_master_path)
#       2 route_index_json = load_json_from_paths(route_index_path)
#       3 billing_code = "J9311"
#
# NameError: name 'load_json_from_paths' is not defined

# %%
scoped_policy_context =resolve_selection_scope(route_index_json, policy_master_json, billing_code, phase, cluster_id)
print(json.dumps(scoped_policy_context, indent=4))
